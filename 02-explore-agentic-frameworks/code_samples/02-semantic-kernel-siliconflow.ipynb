# %% [markdown]
# # Semantic Kernel + SiliconFlow
#
# 本示例与同目录的 GitHub Models 版本逻辑完全一致，仅将 LLM 提供方替换为 SiliconFlow（兼容 OpenAI 接口）。

# %% [markdown]
# ## 导入依赖

# %%
import json
import os

from typing import Annotated

from dotenv import load_dotenv

from IPython.display import display, HTML

from openai import AsyncOpenAI

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent, StreamingTextContent
from semantic_kernel.functions import kernel_function

# %% [markdown]
# ## 创建客户端（SiliconFlow）
#
# 本示例使用 SiliconFlow 的 OpenAI 兼容接口。请在本地 `.env` 中设置 `SILICONFLOW_API_KEY`，并使用 `base_url="https://api.siliconflow.cn/v1"`。可根据需要替换模型 ID（示例使用 `Qwen/Qwen2.5-72B-Instruct`）。

# %%
import random

# 与原示例一致的示例插件
class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
# 创建 SiliconFlow 客户端与 SK 连接器
load_dotenv()
client = AsyncOpenAI(
    api_key=os.environ.get("SILICONFLOW_API_KEY"),
    base_url="https://api.siliconflow.cn/v1",
)

chat_completion_service = OpenAIChatCompletion(
    ai_model_id="Qwen/Qwen3-VL-235B-A22B-Instruct",
    async_client=client,
)

# %% [markdown]
# ## 创建 Agent
#
# 保持与原示例相同的指令与插件。

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service,
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## 运行 Agent
#
# 流式输出与函数调用展示逻辑保持一致。

# %%
user_inputs = [
    "Plan me a day trip.",
    "I don't like that destination. Plan me another vacation.",
]

async def main():
    thread: ChatHistoryAgentThread | None = None

    for user_input in user_inputs:
        html_output = (
            f"<div style='margin-bottom:10px'>"
            f"<div style='font-weight:bold'>User:</div>"
            f"<div style='margin-left:20px'>{user_input}</div></div>"
        )

        agent_name = None
        full_response: list[str] = []
        function_calls: list[str] = []

        # Buffer to reconstruct streaming function call
        current_function_name = None
        argument_buffer = ""

        async for response in agent.invoke_stream(
            messages=user_input,
            thread=thread,
        ):
            thread = response.thread
            agent_name = response.name
            content_items = list(response.items)

            for item in content_items:
                if isinstance(item, FunctionCallContent):
                    if item.function_name:
                        current_function_name = item.function_name

                    # Accumulate arguments (streamed in chunks)
                    if isinstance(item.arguments, str):
                        argument_buffer += item.arguments
                elif isinstance(item, FunctionResultContent):
                    # Finalize any pending function call before showing result
                    if current_function_name:
                        formatted_args = argument_buffer.strip()
                        try:
                            parsed_args = json.loads(formatted_args)
                            formatted_args = json.dumps(parsed_args)
                        except Exception:
                            pass  # leave as raw string

                        function_calls.append(f"Calling function: {current_function_name}({formatted_args})")
                        current_function_name = None
                        argument_buffer = ""

                    function_calls.append(f"\nFunction Result:\n\n{item.result}")
                elif isinstance(item, StreamingTextContent) and item.text:
                    # full_response.append(item.text)
                    text = item.text
                    # 智能空格补全
                    if full_response and not full_response[-1].endswith((" ", "\n")) and not text.startswith((" ", "\n", ".", ",", "!", "?")):
                        full_response.append(" ")
                    full_response.append(text)

        if function_calls:
            html_output += (
                "<div style='margin-bottom:10px'>"
                "<details>"
                "<summary style='cursor:pointer; font-weight:bold; color:#0066cc;'>Function Calls (click to expand)</summary>"
                "<div style='margin:10px; padding:10px; background-color:#f8f8f8; "
                "border:1px solid #ddd; border-radius:4px; white-space:pre-wrap; font-size:14px; color:#333;'>"
                f"{chr(10).join(function_calls)}"
                "</div></details></div>"
            )

        html_output += (
            "<div style='margin-bottom:20px'>"
            f"<div style='font-weight:bold'>{agent_name or 'Assistant'}:</div>"
            f"<div style='margin-left:20px; white-space:pre-wrap'>{''.join(full_response)}</div></div><hr>"
        )

        display(HTML(html_output))

await main()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Plan me a day trip.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>Sure! To make the most of your day trip, I 'll need to know a bit more about your preferences. However, since you haven 't specified a destination, I can suggest a random one for you. Would you like me to proceed with a random destination, or do you have any particular preferences such as the type of location ( e.g., beach, mountains, historical, cultural )? If you 're okay with a random destination, I 'll go ahead and suggest one for you. Sure, let 's plan a day trip to Cape Town, South Africa! Here ’s a suggested itinerary : ### Morning : - ** 9 : 0 0 AM : Breakfast at The Test Kitchen ** - Start your day with a delicious breakfast at one of Cape Town 's most famous restaurants, The Test Kitchen. Enjoy a casual meal with a view. - ** 1 1 : 0 0 AM : Visit the V &A Water front ** - Take a stroll around the V &A Water front, a bustling area with shops, restaurants, and historical sites. You can also catch a boat to Rob ben Island if you 're interested in history. ### After noon : - ** 1 : 0 0 PM : Lunch at The Pot Luck Club ** - Head to The Pot Luck Club for a unique dining experience. This restaurant offers a variety of small plates, perfect for sharing and trying different flavors. - ** 3 : 0 0 PM : Table Mountain A erial Cable way ** - Take a cable car up to the top of Table Mountain. The views from the summit are breathtaking, and you can explore the trails and enjoy the flora and fauna. ### Evening : - ** 6 : 0 0 PM : Visit the Bo -K a ap District ** - Explore the colorful streets of the Bo -K a ap district. This historic neighborhood is known for its brightly painted houses and rich cultural heritage. - ** 8 : 0 0 PM : Dinner at Gold ** - End your day with a fantastic dinner at Gold, a lively restaurant that showcases African cuisine. The ambiance and live music will make for a memorable evening. Would you like me to add or adjust any part of this itinerary?</div></div><hr>
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>I don't like that destination. Plan me another vacation.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>I apologize for the mistake. Let 's try this again. Would you prefer a specific type of location ( e.g., beach, mountains, historical, cultural ) for your day trip, or would you like me to suggest another random destination?</div></div><hr>
